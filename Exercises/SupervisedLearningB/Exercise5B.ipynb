# %% [markdown]
# # 5.3 Iris flower extended data set –Classification using different Algorithms
#
# Continuing with the Iris dataset, suppose that we have Iris already identified in the 3 classes but
# now we have also the Iris packed in different types of packages: “Simple – 0”, “Gift – 1” and “Luxury
# – 3”. We also have a new variable “price” with three possibilities: “Low”, “Medium”, “High”.
#
# We have now a different classification problem in which we want to predict the “price” classification
# based on the remaining characteristics: sepal_length_cm, sepal_width_cm, petal_length_cm,
# petal_width_cm, iris_type, and package.

# %% [markdown]
# #### a) Create a new notebook and start by importing the needed libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %% [markdown]
# #### b) Read the data from the CSV file and check the data using the head(), describe(), and other Pandas commands.

# %%
df = pd.read_csv(os.getcwd() + "/iris-data-new2.csv")
df.head()
df.describe()
sb.pairplot(df, hue='iris_type')

# %% [markdown]
# #### c) Using only the attribute sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, fit a simple decision tree model to the data.

# %%
x = df[['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm']].values
y = df['price'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=50, test_size=0.25)
dtc = DecisionTreeClassifier(criterion='entropy')
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# #### d) Analyse the accuracy, precision, recall and f-measure achieved.

# %%
print('Accuracy Score: ', accuracy_score(y_test, dtc.predict(x_test)))
print('Precision Score: ', precision_score(y_test, dtc.predict(x_test), average='weighted'))
print('Recall Score: ', recall_score(y_test, dtc.predict(x_test), average='weighted'))
print('F-Measure Score: ', f1_score(y_test, dtc.predict(x_test), average='weighted'))
# Out:
# Accuracy Score:  0.7894736842105263
# Precision Score:  0.813475997686524
# Recall Score:  0.7894736842105263
# F-Measure Score:  0.7890846851052242

# %% [markdown]
# #### e) Create and analyse a confusion matrix of the results.

# %%
y_pred = dtc.predict(x_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 4,  0,  3],
#        [ 0, 18,  2],
#        [ 0,  3,  8]], dtype=int64)

# %% [markdown]
# #### f) Using only the attribute sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, fit a simple nearest neighbor model to the data.

# %%
knc = KNeighborsClassifier(n_neighbors=3)
knc.fit(x_train, y_train)
sb.scatterplot(x=x[:, 0], y=x[:, 1], hue=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### g) Analyse the accuracy, precision, recall and f-measure achieved.

# %%
print('Accuracy Score: ', accuracy_score(y_test, knc.predict(x_test)))
print('Precision Score: ', precision_score(y_test, knc.predict(x_test), average='weighted'))
print('Recall Score: ', recall_score(y_test, knc.predict(x_test), average='weighted'))
print('F-Measure Score: ', f1_score(y_test, knc.predict(x_test), average='weighted'))
# Out:
# Accuracy Score:  0.7894736842105263
# Precision Score:  0.8479102167182662
# Recall Score:  0.7894736842105263
# F-Measure Score:  0.7988721804511278

# %% [markdown]
# #### h) Fit distinct models such as decision trees, SVM and neural networks to the data and try different configuration parameters.

# %%
svm = SVC(kernel='linear')
svm.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# #### i) Analyse the accuracy, precision, recall and f-measure achieved for distinct models.

# %%
print('Accuracy Score: ', accuracy_score(y_test, svm.predict(x_test)))
print('Precision Score: ', precision_score(y_test, svm.predict(x_test), average='weighted'))
print('Recall Score: ', recall_score(y_test, svm.predict(x_test), average='weighted'))
print('F-Measure Score: ', f1_score(y_test, svm.predict(x_test), average='weighted'))
# Out:
# Accuracy Score:  0.7894736842105263
# Precision Score:  0.8257309941520469
# Recall Score:  0.7894736842105263
# F-Measure Score:  0.7971269266283117
